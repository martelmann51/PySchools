# %% [markdown]
# # PyCity Schools Analysis
#
# * As a whole, schools with higher budgets, did not yield better test results. By contrast, schools with higher spending per student actually (\$645-675) underperformed compared to schools with smaller budgets (<\$585 per student).
#
# * As a whole, smaller and medium sized schools dramatically out-performed large sized schools on passing math performances (89-91% passing vs 67%).
#
# * As a whole, charter schools out-performed the public district schools across all metrics. However, more analysis will be required to glean if the effect is due to school practices or the fact that charter schools tend to serve smaller student populations per school.
# ---

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

school_data_complete
# Out:
#        Student ID         student_name gender grade         school_name  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 3               3    Dr. Richard Scott      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# ...

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
#Calculate Total Number of Schools
TotalSchools = school_data_complete["school_name"].nunique()

TotalSchools
# Out:
# 15

# %%
#Calculate Total Number of Students of District
TotalStudents = int(school_data_complete["Student ID"].nunique())

TotalStudents
# Out:
# 39170

# %%
#Calculate Total Budget of District
UniqueBudget = school_data_complete["budget"].unique()


TotalBudget = int(UniqueBudget.sum())

TotalBudget
# Out:
# 24649428

# %%
#Calculate Per Student Budget

PerStudentBudget = (int(TotalBudget/TotalStudents))


PerStudentBudget
# Out:
# 629

# %%
#Calculate Average Math Score

AverageMathScore = round(school_data_complete["math_score"].mean(),2)

AverageMathScore
# Out:
# 78.99

# %%
#Calculate Average Reading Score

AverageReadingScore = round(school_data_complete["reading_score"].mean(),2)

AverageReadingScore
# Out:
# 81.88

# %%
#Calculate Overall Passing Rate

OverallPassingRate = round((AverageMathScore + AverageReadingScore)/2,2)

OverallPassingRate
# Out:
# 80.44

# %%
PassingMath = school_data_complete.loc[school_data_complete["math_score"] >= 70]
StudentsPassingMath = PassingMath["student_name"].nunique()

StudentsPassingMath
# Out:
# 25426

# %%
#Percentage of Students with Passing Math Scores

Percentage_Passing_Math = round((StudentsPassingMath/TotalStudents)*100,2)

Percentage_Passing_Math
# Out:
# 64.91

# %%
PassingReading = school_data_complete.loc[school_data_complete["reading_score"] >= 70]
StudentsPassingReading = PassingReading["student_name"].nunique()

StudentsPassingReading
# Out:
# 28587

# %%
#Percentage of Students with Passing Reading Scores

Percentage_Passing_Reading = round((StudentsPassingReading/TotalStudents)*100,2)

Percentage_Passing_Reading
# Out:
# 72.98

# %%
#DistrictSummary

district_summary_df = pd.DataFrame({"Total Schools": [TotalSchools], 
                                    "Total Students": [TotalStudents], 
                                    "Total Budget": [TotalBudget],
                                    "Budget Per Student": [PerStudentBudget],
                                    "Average Math Score": [AverageMathScore],
                                    "Average Reading Score": [AverageReadingScore],
                                    "Overall Passing Rate": [OverallPassingRate],
                                    "Percentage of Students Passing Math": [Percentage_Passing_Math],
                                    "Percentage of Students Passing Reading": [Percentage_Passing_Reading]
                                   })
district_summary_df["Total Students"] = district_summary_df["Total Students"].map("{:,}".format)
district_summary_df["Total Budget"] = district_summary_df["Total Budget"].map("{:,.2f}".format)
district_summary_df["Budget Per Student"] = district_summary_df["Budget Per Student"].map("{:,.2f}".format)
district_summary_df["Percentage of Students Passing Math"] = district_summary_df["Percentage of Students Passing Math"].map("{:}%".format)
district_summary_df["Percentage of Students Passing Reading"] = district_summary_df["Percentage of Students Passing Reading"].map("{:}%".format)
district_summary_df
                                
district_summary_df
# Out:
#    Total Schools Total Students   Total Budget Budget Per Student  \
# 0             15         39,170  24,649,428.00             629.00
#
#    Average Math Score  Average Reading Score  Overall Passing Rate  \
# 0               78.99                  81.88                 80.44
#
#   Percentage of Students Passing Math Percentage of Students Passing Reading
# 0                              64.91%                                 72.98%

# %%
#Per Student Budget


group_school_data = school_data_complete.groupby(["school_name"])
Total_Students = group_school_data["student_name"].count()
Average_Student_Math_Scores = round(group_school_data["math_score"].mean(),2)
Average_Student_Reading_Scores = round(group_school_data["reading_score"].mean(),2)
School_Types = school_data.set_index("school_name")["type"]
Total_School_Budget = round(school_data.set_index("school_name")["budget"],2)
Budget_Per_Student = round(Total_School_Budget/Total_Students,2)
Passing_Reading = student_data.loc[student_data["reading_score"] >= 70]
Group_Passing_Reading = Passing_Reading.groupby(["school_name"])
Count_Passing_Reading = Group_Passing_Reading["reading_score"].count()
Percent_Passing_Reading = round((Count_Passing_Reading/Total_Students*100),2)
Passing_Math = student_data.loc[student_data["math_score"] >=70]
Group_Passing_Math = Passing_Math.groupby(["school_name"])
Count_Passing_Math = Group_Passing_Math["math_score"].count()
Percent_Passing_Math = round((Count_Passing_Math/Total_Students*100),2)
Overall_Passing_Rate = round(((Percent_Passing_Reading + Percent_Passing_Math)/2),2)

# %%
#School Summary

school_summary_df = pd.DataFrame({"School Type": School_Types,
                                  "Total Students": Total_Students,
                                  "Total School Budget": Total_School_Budget,
                                  "Budget Per Student": Budget_Per_Student,
                                    "Average Math Score": Average_Student_Math_Scores,
                                     "Average Reading Score": Average_Student_Reading_Scores,
                                     "Percent Passing Reading": Percent_Passing_Reading,
                                     "Percent Passing Math": Percent_Passing_Math,
                                     "Overall Passing Rate": Overall_Passing_Rate})

school_summary_df["Total Students"] = school_summary_df["Total Students"]
school_summary_df["Total School Budget"] = school_summary_df["Total School Budget"].map("{:,.2f}".format)
school_summary_df["Budget Per Student"] = school_summary_df[("Budget Per Student")]
school_summary_df["Percent Passing Math"] = school_summary_df["Percent Passing Math"]
school_summary_df["Percent Passing Reading"] = school_summary_df["Percent Passing Reading"]
school_summary_df["Overall Passing Rate"] = school_summary_df["Overall Passing Rate"]


school_summary_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976        3,124,928.00
# Cabrera High School       Charter            1858        1,081,356.00
# Figueroa High School     District            2949        1,884,411.00
# Ford High School         District            2739        1,763,916.00
# Griffin High School       Charter            1468          917,500.00
# Hernandez High School    District            4635        3,022,020.00
# Holden High School        Charter             427          248,087.00
# Huang High School        District            2917        1,910,635.00
# Johnson High School      District            4761        3,094,650.00
# Pena High School          Charter             962          585,858.00
# Rodriguez High School    District            3999        2,547,363.00
# Shelton High School       Charter            1761        1,056,600.00
# ...

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
#Top Performing Schools

TopPerformingSchools = school_summary_df.sort_values("Overall Passing Rate", ascending=False)

TopPerformingSchools.head(5)
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858        1,081,356.00
# Thomas High School      Charter            1635        1,043,130.00
# Pena High School        Charter             962          585,858.00
# Griffin High School     Charter            1468          917,500.00
# Wilson High School      Charter            2283        1,319,574.00
#
#                      Budget Per Student  Average Math Score  \
# Cabrera High School               582.0               83.06
# Thomas High School                638.0               83.42
# Pena High School                  609.0               83.84
# Griffin High School               625.0               83.35
# Wilson High School                578.0               83.27
#
#                      Average Reading Score  Percent Passing Reading  \
# Cabrera High School                  83.98                    97.04
# ...

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
#Worst Performing Schools

WorstPerformingSchools = school_summary_df.sort_values("Overall Passing Rate", ascending=True)

WorstPerformingSchools.head(5)
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999        2,547,363.00
# Figueroa High School     District            2949        1,884,411.00
# Huang High School        District            2917        1,910,635.00
# Johnson High School      District            4761        3,094,650.00
# Ford High School         District            2739        1,763,916.00
#
#                        Budget Per Student  Average Math Score  \
# Rodriguez High School               637.0               76.84
# Figueroa High School                639.0               76.71
# Huang High School                   655.0               76.63
# Johnson High School                 650.0               77.07
# Ford High School                    644.0               77.10
#
#                        Average Reading Score  Percent Passing Reading  \
# Rodriguez High School                  80.74                    80.22
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
Grade_9 = student_data.loc[student_data["grade"] =="9th"]
Grade_10 = student_data.loc[student_data["grade"] =="10th"]
Grade_11 = student_data.loc[student_data["grade"] =="11th"]
Grade_12 = student_data.loc[student_data["grade"] =="12th"]
Group_Grade_9 = Grade_9.groupby(["school_name"])
Group_Grade_10 = Grade_10.groupby(["school_name"])
Group_Grade_11 = Grade_11.groupby(["school_name"])
Group_Grade_12 = Grade_12.groupby(["school_name"])
Grade9_Average_Math = Group_Grade_9["math_score"].mean()
Grade10_Average_Math = Group_Grade_10["math_score"].mean()
Grade11_Average_Math = Group_Grade_11["math_score"].mean()
Grade12_Average_Math = Group_Grade_12["math_score"].mean()



math_by_grade = pd.DataFrame({"9th": Grade9_Average_Math,
                              "10th": Grade10_Average_Math,
                              "11th": Grade11_Average_Math,
                              "12th": Grade12_Average_Math
                                  })
math_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
Grade_9 = student_data.loc[student_data["grade"] =="9th"]
Grade_10 = student_data.loc[student_data["grade"] =="10th"]
Grade_11 = student_data.loc[student_data["grade"] =="11th"]
Grade_12 = student_data.loc[student_data["grade"] =="12th"]
Group_Grade_9 = Grade_9.groupby(["school_name"])
Group_Grade_10 = Grade_10.groupby(["school_name"])
Group_Grade_11 = Grade_11.groupby(["school_name"])
Group_Grade_12 = Grade_12.groupby(["school_name"])
Grade9_Average_Reading = Group_Grade_9["reading_score"].mean()
Grade10_Average_Reading = Group_Grade_10["reading_score"].mean()
Grade11_Average_Reading = Group_Grade_11["reading_score"].mean()
Grade12_Average_Reading = Group_Grade_12["reading_score"].mean()



reading_by_grade = pd.DataFrame({"9th": Grade9_Average_Reading,
                              "10th": Grade10_Average_Reading,
                              "11th": Grade11_Average_Reading,
                              "12th": Grade12_Average_Reading
                                  })
reading_by_grade
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

school_summary_df["Spending Ranges (Per Student)"] = pd.cut(school_summary_df["Budget Per Student"], spending_bins, labels=group_names)


school_summary_df

spending_group = school_summary_df.groupby("Spending Ranges (Per Student)")

spending_group

spending_group[["Average Math Score", 
                "Average Reading Score", 
                "Percent Passing Reading", 
                "Percent Passing Math", 
                "Overall Passing Rate"]].mean()
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                   83.452500              83.935000
# $585-615                                83.600000              83.885000
# $615-645                                79.078333              81.891667
# $645-675                                76.996667              81.026667
#
#                                Percent Passing Reading  Percent Passing Math  \
# Spending Ranges (Per Student)
# <$585                                        96.610000             93.460000
# $585-615                                     95.900000             94.230000
# $615-645                                     86.106667             75.668333
# $645-675                                     81.133333             66.163333
#
#                                Overall Passing Rate
# Spending Ranges (Per Student)
# <$585                                     95.035000
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names_size = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

school_summary_df["School Size"] = pd.cut(school_summary_df["Total Students"], size_bins, labels=group_names_size)

size_group = school_summary_df.groupby("School Size")

size_group

size_group[["Average Math Score", 
                "Average Reading Score", 
                "Percent Passing Reading", 
                "Percent Passing Math", 
                "Overall Passing Rate"]].mean()
# Out:
#                     Average Math Score  Average Reading Score  \
# School Size
# Small (<1000)                   83.820               83.92500
# Medium (1000-2000)              83.374               83.86800
# Large (2000-5000)               77.745               81.34375
#
#                     Percent Passing Reading  Percent Passing Math  \
# School Size
# Small (<1000)                      96.10000              93.55000
# Medium (1000-2000)                 96.79000              93.59800
# Large (2000-5000)                  82.76625              69.96375
#
#                     Overall Passing Rate
# School Size
# Small (<1000)                    94.8250
# Medium (1000-2000)               95.1920
# Large (2000-5000)                76.3675

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.

# %%
type_group = school_summary_df.groupby("School Type")


type_group[["Average Math Score", 
                "Average Reading Score", 
                "Percent Passing Reading", 
                "Percent Passing Math", 
                "Overall Passing Rate"]].mean()
# Out:
#              Average Math Score  Average Reading Score  \
# School Type
# Charter               83.472500              83.897500
# District              76.955714              80.965714
#
#              Percent Passing Reading  Percent Passing Math  \
# School Type
# Charter                    96.586250             93.620000
# District                   80.798571             66.548571
#
#              Overall Passing Rate
# School Type
# Charter                 95.102500
# District                73.675714
